# %% [markdown]
# # 🤸 Python Gymnastics — Problem‑Based Trick Training
# Each task hides a Python trick, but **students must infer** the technique.
# This version includes **solutions**.

# %% [markdown]
# ## 1 — The Mysterious Trio
#
# You receive a tuple of three moves: `("split", "cartwheel", "somersault")`. Assign each move to its own variable in a single elegant instruction.

# %% [markdown]
# ## 2 — The Accidental Mix‑up
#
# Two gymnasts mixed up their moves: `split = 'A'`, `cartwheel = 'B'`. Restore the correct order in the cleanest way possible.

# %% [markdown]
# ## 3 — The Lead Performer
#
# From the list `moves = ["flip", "twist", "tumble", "vault"]`, isolate the first move as the star (`lead_move`) and keep the rest together.

# %% [markdown]
# ## 4 — The Coach Wants It LOUD
#
# You must transform `gym_series = ["flip", "turn", "jump"]` into a list where the coach can read them from far away.

# %% [markdown]
# ## 5 — Height Selection
#
# Given `gym_heights = [0.8, 1.2, 1.0, 1.6]`, keep only the tricks that reach competition height (≥ 1.0).

# %% [markdown]
# ## 6 — Measuring the Choreography
#
# You are asked to build a mapping of moves to their number of letters for `['roll', 'split', 'spin']`.

# %% [markdown]
# ## 7 — Alphabet Soup
#
# From the list `['cartwheel', 'somersault', 'split']`, find all unique letters used across the moves.

# %% [markdown]
# ## 8 — Judge Pairings
#
# You receive two lists: `gymnasts = ["Lia","Mika","Zoe"]` and `scores = [9.4,9.1,9.7]`. Create structured pairs for the scoreboard.

# %% [markdown]
# ## 9 — Numbering the Routine
#
# A routine `['jump','roll','flip']` needs numbered steps starting at 0. Produce pairs of step index and move.

# %% [markdown]
# ## 10 — The Showmaster Function
#
# Write a function that can take any number of moves and any number of judges’ scores, then prints them cleanly.

# %% [markdown]
# ## 11 — Ranking Acrobatics
#
# Given `acro = [("split", 2), ("flip", 3), ("vault", 1)]`, sort them by difficulty (integer value).

# %% [markdown]
# ## 12 — The Infinite Warm‑up
#
# Create something that produces the lengths of `['flip','turn','jump']` **one at a time** when iterated.
